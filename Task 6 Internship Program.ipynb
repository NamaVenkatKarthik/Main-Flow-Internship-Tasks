# %%
# Applying  advanced statistical and analytical methods to solve complex problems. 
### This task involves
## Data Visualization Tools And Techniques
## Exploratory Data Analysis(EDA)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataa =pd.read_csv('IPL_2023_DATASET.csv')
dataa
# Out:
#      Unnamed: 0             Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0             0        Shivam Mavi    4000000        BOWLER              6.0
# 1             1      Joshua Little    5000000        BOWLER              4.4
# 2             2    Kane Williamson   20000000       BATSMAN              2.0
# 3             3        K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4             4       Mohit Sharma    5000000        BOWLER              0.5
# ..          ...                ...        ...           ...              ...
# 563         563        Dhruv Patel        NaN   ALL-ROUNDER              NaN
# 564         564    Jack Prestwidge        NaN   ALL-ROUNDER              NaN
# 565         565     Aditya Sarvate        NaN   ALL-ROUNDER              NaN
# 566         566      Sagar Solanki        NaN   ALL-ROUNDER              NaN
# 567         567  Prenelan Subrayen        NaN   ALL-ROUNDER              NaN
#
# ...

# %%
dataa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       568 non-null    int64
#  1   Player           568 non-null    object
#  2   Base Price       243 non-null    object
#  3   TYPE             568 non-null    object
#  4   COST IN ₹ (CR.)  243 non-null    float64
#  5   Cost IN $ (000)  243 non-null    float64
#  6   2022 Squad       230 non-null    object
#  7   Team             568 non-null    object
#  8   Base Price IN ₹  325 non-null    float64
#  9   Base Price IN $  325 non-null    float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 44.5+ KB

# %%
dataa.columns.values
# Out:
# array(['Unnamed: 0', 'Player', 'Base Price', 'TYPE', 'COST IN ₹ (CR.)',
#        'Cost IN $ (000)', '2022 Squad', 'Team', 'Base Price IN ₹',
#        'Base Price IN $'], dtype=object)

# %%
dataa.hist(bins = 100, grid = False , figsize=(10,10));

# %%
dataa.describe()
# Out:
#        Unnamed: 0  COST IN ₹ (CR.)  Cost IN $ (000)  Base Price IN ₹  \
# count  568.000000       243.000000       243.000000     3.250000e+02
# mean   283.500000         0.687243        82.469136     3.453846e+06
# std    164.111751         2.511700       301.404032     3.530864e+06
# min      0.000000         0.000000         0.000000     1.500000e+06
# 25%    141.750000         0.000000         0.000000     2.000000e+06
# 50%    283.500000         0.000000         0.000000     2.000000e+06
# 75%    425.250000         0.200000        24.000000     4.000000e+06
# max    567.000000        18.500000      2220.000000     2.000000e+07
#
#        Base Price IN $
# count       325.000000
# mean      41446.153846
# std       42370.365390
# min       18000.000000
# 25%       24000.000000
# 50%       24000.000000
# 75%       48000.000000
# max      240000.000000

# %%
dataa.Player.value_counts()
# Out:
# Player
# Akash Singh            2
# Prince Yadav           2
# Shivam Sharma          2
# Shivam Mavi            1
# Bharat Sharma          1
#                       ..
# Suyash Prabhudessai    1
# Virat Kohli            1
# Karn Sharma            1
# Wanindu Hasaranga      1
# Prenelan Subrayen      1
# Name: count, Length: 565, dtype: int64

# %%
# Framing and Solving the Questions with the help of plotting graphs..Questions

# %%
#"1.How many Teams and members are listed in the dataset?"
dataa['Team'].value_counts()
# Out:
# Team
# Unsold                         325
# Gujarat Titans                  25
# Chennai Super Kings             25
# Delhi Capitals                  25
# Lucknow Super Giants            25
# Royal Challengers Bangalore     25
# Rajasthan Royals                25
# Sunrisers Hyderabad             25
# Mumbai Indians                  24
# Kolkata Knight Riders           22
# Punjab Kings                    22
# Name: count, dtype: int64

# %%
# Plotting the Bar chart...
dataa['Team'].value_counts().plot(kind='bar',color=['black'])
plt.xlabel("teams")
plt.ylabel("members of the team")
plt.show()

# %%
#Plotting the pie chart...
dataa['TYPE'].value_counts().plot(kind='bar',color=['green'])
plt.xlabel("teams")
plt.ylabel("members of each team")
plt.show()

# %%
dataa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       568 non-null    int64
#  1   Player           568 non-null    object
#  2   Base Price       243 non-null    object
#  3   TYPE             568 non-null    object
#  4   COST IN ₹ (CR.)  243 non-null    float64
#  5   Cost IN $ (000)  243 non-null    float64
#  6   2022 Squad       230 non-null    object
#  7   Team             568 non-null    object
#  8   Base Price IN ₹  325 non-null    float64
#  9   Base Price IN $  325 non-null    float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 44.5+ KB

# %%
# Loading another dataset...
df=pd.read_csv('disney_plus_titles.csv')
df
# Out:
#      show_id     type                           title  \
# 0         s1    Movie                   A Spark Story
# 1         s2    Movie                  Spooky Buddies
# 2         s3    Movie          The Fault in Our Stars
# 3         s4  TV Show                 Dog: Impossible
# 4         s5  TV Show  Spidey And His Amazing Friends
# ...      ...      ...                             ...
# 1363   s1364    Movie          The Sword in the Stone
# 1364   s1365    Movie                 Those Calloways
# 1365   s1366  TV Show            Disney Kirby Buckets
# 1366   s1367  TV Show                  Disney Mech-X4
# 1367   s1368  TV Show              Imagination Movers
#
#                         director  \
# 0     Jason Sterman, Leanne Dare
# 1                   Robert Vince
# 2                     Josh Boone
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1363         Wolfgang Reitherman
# 1364                Norman Tokar
# ...

# %%
df.hist(bins = 50, grid = False , figsize=(8,4));

# %%
df.columns.values
# Out:
# array(['show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description'], dtype=object)

# %%
df.isna().sum()
# Out:
# country    0
# titles     0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#         country  titles
# 0           USA     150
# 1            UK     120
# 2        Canada     100
# 3     Australia      90
# 4       Germany      85
# 5        France      80
# 6         Italy      75
# 7         Spain      70
# 8   Netherlands      65
# 9         India      60
# 10        Japan      55

# %%
Questions = ["1. How many movies and TV shows are listed in the dataset?",
             "2. Which country has produced the highest number of titles?",
             "3. What is the distribution of titles based on their ratings?"]

# %%
data = {
    'type': ['Movie', 'TV Show', 'Movie', 'TV Show', 'Movie', 'Movie', 'TV Show', 'Movie'],
}

type_counts = df['type'].value_counts()  
    
df = pd.DataFrame(data)
plt.figure(figsize=(6, 3))
sns.barplot(x=type_counts.index, y=type_counts.values, palette='viridis')
plt.title('Number of Movies and TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
# Question 1: How many movies and TV shows are listed in the dataset?
disney_data = pd.DataFrame(data)
type_counts = disney_data['type'].value_counts()
plt.figure(figsize=(6, 4))
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff'])
plt.title('Distribution of Movies and TV Shows')
plt.axis('equal') 
plt.show()

# %%
# Plot the top 10 countries by number of titles

data = {
    'country': ['USA', 'UK', 'Canada', 'Australia', 'Germany', 'France', 'Italy', 'Spain', 'Netherlands', 'India', 'Japan'],
    'titles': [150, 120, 100, 90, 85, 80, 75, 70, 65, 60, 55]
}
df = pd.DataFrame(data)
country_counts = df.set_index('country')['titles']
country_counts = country_counts.sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 4))
sns.barplot(x=country_counts.index, y=country_counts.values, palette='viridis')
plt.title('Top 10 Countries by Number of Titles')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Question 2: Which country has produced the highest number of titles?

data = {
    'country': ['USA', 'UK', 'Canada', 'USA', 'UK', 'USA', 'France', 'Germany', 'UK', 'India', 'Canada', 'France', 'Germany', 'India']
}
disney_data = pd.DataFrame(data)
country_counts = disney_data['country'].value_counts().head(10)
plt.figure(figsize=(5,4))
plt.pie(
    country_counts,
    labels=country_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette('viridis', len(country_counts))
)
plt.title('Top 10 Countries by Number of Titles')
plt.axis('equal')  
plt.show()

# %%
# Question 3: What is the distribution of titles based on their ratings?
#Plot the distribution of titles based on their ratings. 

data = {
    'rating': ['PG', 'PG', 'R', 'PG', 'G', 'PG', 'R', 'PG', 'G', 'PG', 'R', 'PG', 'R', 'G']
}
disney_data = pd.DataFrame(data)
rating_counts = disney_data['rating'].value_counts()
plt.figure(figsize=(6, 5))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(rating_counts)))
plt.title('Distribution of Titles by Rating')
plt.axis('equal')  
plt.show()
